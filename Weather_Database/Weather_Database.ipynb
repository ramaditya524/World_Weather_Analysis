# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
city_url = url + "&q=" + "vrangel"
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': 133.0839, 'lat': 42.7297},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 48.04,
#   'feels_like': 46.49,
#   'temp_min': 48.04,
#   'temp_max': 48.04,
#   'pressure': 1025,
#   'humidity': 52,
#   'sea_level': 1025,
#   'grnd_level': 1024},
#  'visibility': 10000,
#  'wind': {'speed': 4.16, 'deg': 320, 'gust': 7.14},
#  'clouds': {'all': 0},
#  'dt': 1617240765,
#  'sys': {'country': 'RU', 'sunrise': 1617223818, 'sunset': 1617269556},
#  'timezone': 36000,
#  'id': 2013258,
#  'name': "Vrangel'",
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather description":city_weather_desc})
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 15 | bulawayo
# Processing Record 2 of Set 15 | poum
# Processing Record 3 of Set 15 | upernavik
# Processing Record 4 of Set 15 | chuy
# Processing Record 5 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 6 of Set 15 | hithadhoo
# Processing Record 7 of Set 15 | kitsuki
# Processing Record 8 of Set 15 | khatanga
# Processing Record 9 of Set 15 | sorland
# Processing Record 10 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 15 | ribeira grande
# Processing Record 12 of Set 15 | barrow
# Processing Record 13 of Set 15 | laguna
# Processing Record 14 of Set 15 | kota bahru
# Processing Record 15 of Set 15 | ostrovnoy
# Processing Record 16 of Set 15 | arraial do cabo
# Processing Record 17 of Set 15 | thompson
# Processing Record 18 of Set 15 | busselton
# Processing Record 19 of Set 15 | port elizabeth
# Processing Record 20 of Set 15 | pisco
# Processing Record 21 of Set 15 | saint-philippe
# Processing Record 22 of Set 15 | carutapera
# Processing Record 23 of Set 15 | hobart
# Processing Record 24 of Set 15 | anadyr
# Processing Record 25 of Set 15 | raga
# Processing Record 26 of Set 15 | manga
# Processing Record 27 of Set 15 | georgetown
# Processing Record 28 of Set 15 | tabuk
# Processing Record 29 of Set 15 | east london
# Processing Record 30 of Set 15 | hermanus
# Processing Record 31 of Set 15 | lasa
# Processing Record 32 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 15 | saldanha
# Processing Record 34 of Set 15 | mataura
# Processing Record 35 of Set 15 | turbat
# Processing Record 36 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 15 | atuona
# Processing Record 38 of Set 15 | rikitea
# Processing Record 39 of Set 15 | fortuna
# Processing Record 40 of Set 15 | camacha
# Processing Record 41 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 42 of Set 15 | yakeshi
# Processing Record 43 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 44 of Set 15 | caravelas
# Processing Record 45 of Set 15 | te anau
# Processing Record 46 of Set 15 | bengkulu
# Processing Record 47 of Set 15 | kavaratti
# Processing Record 48 of Set 15 | mar del plata
# Processing Record 49 of Set 15 | okakarara
# Processing Record 50 of Set 15 | fukue
# Processing Record 1 of Set 16 | punta arenas
# Processing Record 2 of Set 16 | qaanaaq
# Processing Record 3 of Set 16 | vaini
# Processing Record 4 of Set 16 | lebu
# Processing Record 5 of Set 16 | lavrentiya
# Processing Record 6 of Set 16 | buin
# Processing Record 7 of Set 16 | cape town
# Processing Record 8 of Set 16 | sironj
# Processing Record 9 of Set 16 | puerto ayora
# Processing Record 10 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 16 | seoul
# Processing Record 13 of Set 16 | kayerkan
# Processing Record 14 of Set 16 | beringovskiy
# Processing Record 15 of Set 16 | maceio
# Processing Record 16 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 16 | bani
# Processing Record 18 of Set 16 | new norfolk
# Processing Record 19 of Set 16 | bethel
# Processing Record 20 of Set 16 | albany
# Processing Record 21 of Set 16 | naze
# Processing Record 22 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 16 | vagur
# Processing Record 24 of Set 16 | hilo
# Processing Record 25 of Set 16 | hamilton
# Processing Record 26 of Set 16 | portel
# Processing Record 27 of Set 16 | kitaotao
# Processing Record 28 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 16 | vestmannaeyjar
# Processing Record 30 of Set 16 | katiola
# Processing Record 31 of Set 16 | tremedal
# Processing Record 32 of Set 16 | berlevag
# Processing Record 33 of Set 16 | hualmay
# Processing Record 34 of Set 16 | kodiak
# Processing Record 35 of Set 16 | nishihara
# Processing Record 36 of Set 16 | baikunthpur
# Processing Record 37 of Set 16 | basoko
# Processing Record 38 of Set 16 | tasiilaq
# Processing Record 39 of Set 16 | nikolskoye
# Processing Record 40 of Set 16 | guanhaes
# Processing Record 41 of Set 16 | tacuba
# Processing Record 42 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 16 | kediri
# Processing Record 44 of Set 16 | lagoa
# Processing Record 45 of Set 16 | port blair
# Processing Record 46 of Set 16 | jamestown
# Processing Record 47 of Set 16 | higuey
# City not found. Skipping...
# Processing Record 48 of Set 16 | kapaa
# Processing Record 49 of Set 16 | almaznyy
# Processing Record 50 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 17 | tuktoyaktuk
# Processing Record 2 of Set 17 | dikson
# Processing Record 3 of Set 17 | bambous virieux
# Processing Record 4 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 17 | uvinza
# Processing Record 6 of Set 17 | ahipara
# Processing Record 7 of Set 17 | los llanos de aridane
# Processing Record 8 of Set 17 | sao joao da barra
# Processing Record 9 of Set 17 | port alfred
# Processing Record 10 of Set 17 | biak
# Processing Record 11 of Set 17 | mahebourg
# Processing Record 12 of Set 17 | oxford
# Processing Record 13 of Set 17 | skibbereen
# Processing Record 14 of Set 17 | yurya
# City not found. Skipping...
# Processing Record 15 of Set 17 | owando
# Processing Record 16 of Set 17 | bluff
# Processing Record 17 of Set 17 | souillac
# Processing Record 18 of Set 17 | arenapolis
# Processing Record 19 of Set 17 | castro
# Processing Record 20 of Set 17 | takoradi
# Processing Record 21 of Set 17 | rodrigues alves
# Processing Record 22 of Set 17 | zhengjiatun
# Processing Record 23 of Set 17 | miri
# Processing Record 24 of Set 17 | troitsko-pechorsk
# Processing Record 25 of Set 17 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 17 | haines junction
# Processing Record 27 of Set 17 | avarua
# Processing Record 28 of Set 17 | jiuquan
# Processing Record 29 of Set 17 | guerrero negro
# Processing Record 30 of Set 17 | lazaro cardenas
# Processing Record 31 of Set 17 | houma
# Processing Record 32 of Set 17 | buraydah
# Processing Record 33 of Set 17 | dingle
# Processing Record 34 of Set 17 | tuatapere
# Processing Record 35 of Set 17 | ushuaia
# Processing Record 36 of Set 17 | kavieng
# Processing Record 37 of Set 17 | naryan-mar
# Processing Record 38 of Set 17 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 17 | torbay
# Processing Record 40 of Set 17 | bathsheba
# Processing Record 41 of Set 17 | vilyuysk
# Processing Record 42 of Set 17 | severo-kurilsk
# Processing Record 43 of Set 17 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 17 | naco
# Processing Record 45 of Set 17 | puerto narino
# Processing Record 46 of Set 17 | bredasdorp
# Processing Record 47 of Set 17 | agadir
# Processing Record 48 of Set 17 | yerofey pavlovich
# Processing Record 49 of Set 17 | iqaluit
# Processing Record 50 of Set 17 | manokwari
# Processing Record 1 of Set 18 | kaitong
# Processing Record 2 of Set 18 | concarneau
# Processing Record 3 of Set 18 | jumla
# Processing Record 4 of Set 18 | kaitangata
# Processing Record 5 of Set 18 | awbari
# Processing Record 6 of Set 18 | dharchula
# Processing Record 7 of Set 18 | nanortalik
# Processing Record 8 of Set 18 | hanna
# Processing Record 9 of Set 18 | belyy yar
# Processing Record 10 of Set 18 | mathbaria
# Processing Record 11 of Set 18 | yulara
# Processing Record 12 of Set 18 | vardo
# Processing Record 13 of Set 18 | cherskiy
# Processing Record 14 of Set 18 | ahuimanu
# Processing Record 15 of Set 18 | bilma
# Processing Record 16 of Set 18 | dzhebariki-khaya
# Processing Record 17 of Set 18 | cidreira
# Processing Record 18 of Set 18 | muros
# Processing Record 19 of Set 18 | kentville
# Processing Record 20 of Set 18 | sibut
# Processing Record 21 of Set 18 | bilibino
# Processing Record 22 of Set 18 | guhagar
# Processing Record 23 of Set 18 | choszczno
# Processing Record 24 of Set 18 | ampanihy
# Processing Record 25 of Set 18 | kannur
# Processing Record 26 of Set 18 | talaya
# Processing Record 27 of Set 18 | sarangarh
# Processing Record 28 of Set 18 | jahrom
# City not found. Skipping...
# Processing Record 29 of Set 18 | quatre cocos
# Processing Record 30 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 18 | paamiut
# Processing Record 32 of Set 18 | altay
# Processing Record 33 of Set 18 | southbridge
# Processing Record 34 of Set 18 | yellowknife
# Processing Record 35 of Set 18 | tulun
# Processing Record 36 of Set 18 | port hardy
# Processing Record 37 of Set 18 | porto velho
# Processing Record 38 of Set 18 | nouadhibou
# Processing Record 39 of Set 18 | atikokan
# Processing Record 40 of Set 18 | cabo san lucas
# Processing Record 41 of Set 18 | lanzhou
# Processing Record 42 of Set 18 | kirkwall
# Processing Record 43 of Set 18 | luderitz
# Processing Record 44 of Set 18 | tutla
# City not found. Skipping...
# Processing Record 45 of Set 18 | colquechaca
# Processing Record 46 of Set 18 | tigil
# Processing Record 47 of Set 18 | kruisfontein
# Processing Record 48 of Set 18 | omboue
# Processing Record 49 of Set 18 | harper
# Processing Record 50 of Set 18 | hasaki
# Processing Record 1 of Set 19 | batie
# Processing Record 2 of Set 19 | clyde river
# Processing Record 3 of Set 19 | auchel
# Processing Record 4 of Set 19 | saint-augustin
# Processing Record 5 of Set 19 | isangel
# Processing Record 6 of Set 19 | herre
# Processing Record 7 of Set 19 | winnemucca
# Processing Record 8 of Set 19 | khandbari
# Processing Record 9 of Set 19 | iquique
# Processing Record 10 of Set 19 | troitskoye
# Processing Record 11 of Set 19 | tsuyama
# Processing Record 12 of Set 19 | kano
# Processing Record 13 of Set 19 | bubaque
# Processing Record 14 of Set 19 | mayumba
# Processing Record 15 of Set 19 | goderich
# Processing Record 16 of Set 19 | bodden town
# Processing Record 17 of Set 19 | cockburn town
# Processing Record 18 of Set 19 | norman wells
# Processing Record 19 of Set 19 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 19 | voloshka
# Processing Record 21 of Set 19 | hovd
# Processing Record 22 of Set 19 | port moresby
# Processing Record 23 of Set 19 | tahta
# Processing Record 24 of Set 19 | ponta do sol
# Processing Record 25 of Set 19 | faya
# Processing Record 26 of Set 19 | aksarka
# Processing Record 27 of Set 19 | lorengau
# Processing Record 28 of Set 19 | yarada
# Processing Record 29 of Set 19 | rebrikha
# Processing Record 30 of Set 19 | paita
# Processing Record 31 of Set 19 | fort nelson
# Processing Record 32 of Set 19 | manali
# Processing Record 33 of Set 19 | hambantota
# Processing Record 34 of Set 19 | saskylakh
# Processing Record 35 of Set 19 | olinda
# Processing Record 36 of Set 19 | cayenne
# Processing Record 37 of Set 19 | kimbe
# Processing Record 38 of Set 19 | karratha
# Processing Record 39 of Set 19 | saint george
# Processing Record 40 of Set 19 | jiexiu
# Processing Record 41 of Set 19 | vostok
# Processing Record 42 of Set 19 | barranca
# Processing Record 43 of Set 19 | tiksi
# Processing Record 44 of Set 19 | ribas do rio pardo
# Processing Record 45 of Set 19 | la romana
# Processing Record 46 of Set 19 | gwembe
# Processing Record 47 of Set 19 | kisangani
# Processing Record 48 of Set 19 | kikwit
# Processing Record 49 of Set 19 | belmonte
# Processing Record 50 of Set 19 | liverpool
# Processing Record 1 of Set 20 | puerto escondido
# Processing Record 2 of Set 20 | sendafa
# Processing Record 3 of Set 20 | tabulbah
# City not found. Skipping...
# Processing Record 4 of Set 20 | vitimskiy
# City not found. Skipping...
# Processing Record 5 of Set 20 | tura
# Processing Record 6 of Set 20 | aberdeen
# Processing Record 7 of Set 20 | baishishan
# Processing Record 8 of Set 20 | naftah
# City not found. Skipping...
# Processing Record 9 of Set 20 | manaure
# Processing Record 10 of Set 20 | inongo
# Processing Record 11 of Set 20 | pemberton
# Processing Record 12 of Set 20 | ola
# Processing Record 13 of Set 20 | luganville
# Processing Record 14 of Set 20 | whitehorse
# Processing Record 15 of Set 20 | drezdenko
# Processing Record 16 of Set 20 | zhigansk
# Processing Record 17 of Set 20 | vytegra
# Processing Record 18 of Set 20 | kipushi
# Processing Record 19 of Set 20 | port hedland
# Processing Record 20 of Set 20 | adrar
# Processing Record 21 of Set 20 | butaritari
# Processing Record 22 of Set 20 | dolores
# Processing Record 23 of Set 20 | paka
# Processing Record 24 of Set 20 | sayyan
# Processing Record 25 of Set 20 | gorontalo
# Processing Record 26 of Set 20 | mecca
# Processing Record 27 of Set 20 | innisfail
# Processing Record 28 of Set 20 | salinas
# Processing Record 29 of Set 20 | morgan hill
# Processing Record 30 of Set 20 | olafsvik
# Processing Record 31 of Set 20 | chokurdakh
# Processing Record 32 of Set 20 | esperance
# Processing Record 33 of Set 20 | carnarvon
# Processing Record 34 of Set 20 | tiarei
# Processing Record 35 of Set 20 | kahului
# Processing Record 36 of Set 20 | ulundi
# Processing Record 37 of Set 20 | shache
# Processing Record 38 of Set 20 | udachnyy
# Processing Record 39 of Set 20 | ilulissat
# Processing Record 40 of Set 20 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 20 | zyryanka
# Processing Record 42 of Set 20 | koumac
# Processing Record 43 of Set 20 | filingue
# Processing Record 44 of Set 20 | bend
# Processing Record 45 of Set 20 | college
# Processing Record 46 of Set 20 | ponta delgada
# Processing Record 47 of Set 20 | auki
# Processing Record 48 of Set 20 | codrington
# Processing Record 49 of Set 20 | hobyo
# Processing Record 50 of Set 20 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 21 | ayagoz
# Processing Record 2 of Set 21 | mihara
# Processing Record 3 of Set 21 | tiznit
# Processing Record 4 of Set 21 | gokak
# Processing Record 5 of Set 21 | phonhong
# Processing Record 6 of Set 21 | miranda
# Processing Record 7 of Set 21 | chapais
# Processing Record 8 of Set 21 | ishigaki
# Processing Record 9 of Set 21 | rendsburg
# Processing Record 10 of Set 21 | sungaipenuh
# Processing Record 11 of Set 21 | acapulco
# Processing Record 12 of Set 21 | carlisle
# Processing Record 13 of Set 21 | kloulklubed
# Processing Record 14 of Set 21 | goure
# Processing Record 15 of Set 21 | khasan
# Processing Record 16 of Set 21 | nagtipunan
# Processing Record 17 of Set 21 | kabanjahe
# Processing Record 18 of Set 21 | athabasca
# Processing Record 19 of Set 21 | roebourne
# Processing Record 20 of Set 21 | evensk
# Processing Record 21 of Set 21 | ustye
# Processing Record 22 of Set 21 | lompoc
# Processing Record 23 of Set 21 | aykhal
# Processing Record 24 of Set 21 | narsaq
# Processing Record 25 of Set 21 | niwari
# Processing Record 26 of Set 21 | kysyl-syr
# Processing Record 27 of Set 21 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 21 | blytheville
# Processing Record 29 of Set 21 | ekhabi
# Processing Record 30 of Set 21 | bastia
# Processing Record 31 of Set 21 | axim
# Processing Record 32 of Set 21 | high prairie
# Processing Record 33 of Set 21 | komsomolskiy
# Processing Record 34 of Set 21 | mehamn
# Processing Record 35 of Set 21 | longyearbyen
# Processing Record 36 of Set 21 | kaputa
# Processing Record 37 of Set 21 | asau
# Processing Record 38 of Set 21 | provideniya
# Processing Record 39 of Set 21 | gravdal
# Processing Record 40 of Set 21 | necochea
# Processing Record 41 of Set 21 | pemba
# Processing Record 42 of Set 21 | blagoyevo
# Processing Record 43 of Set 21 | amahai
# Processing Record 44 of Set 21 | veraval
# Processing Record 45 of Set 21 | pentecoste
# Processing Record 46 of Set 21 | labuhan
# Processing Record 47 of Set 21 | sitka
# Processing Record 48 of Set 21 | honiara
# Processing Record 49 of Set 21 | bambanglipuro
# Processing Record 50 of Set 21 | atasu
# Processing Record 1 of Set 22 | de aar
# Processing Record 2 of Set 22 | tarakan
# Processing Record 3 of Set 22 | bella union
# Processing Record 4 of Set 22 | srednekolymsk
# Processing Record 5 of Set 22 | la asuncion
# Processing Record 6 of Set 22 | newport
# Processing Record 7 of Set 22 | husavik
# Processing Record 8 of Set 22 | pandan
# Processing Record 9 of Set 22 | salalah
# Processing Record 10 of Set 22 | taoudenni
# Processing Record 11 of Set 22 | kolokani
# Processing Record 12 of Set 22 | san felipe
# Processing Record 13 of Set 22 | baruun-urt
# Processing Record 14 of Set 22 | rawson
# Processing Record 15 of Set 22 | hit
# Processing Record 16 of Set 22 | dicabisagan
# Processing Record 17 of Set 22 | klaksvik
# Processing Record 18 of Set 22 | jiaohe
# Processing Record 19 of Set 22 | letka
# Processing Record 20 of Set 22 | alvorada
# Processing Record 21 of Set 22 | santa maria
# Processing Record 22 of Set 22 | marsh harbour
# Processing Record 23 of Set 22 | marathon
# Processing Record 24 of Set 22 | labuan
# Processing Record 25 of Set 22 | inirida
# Processing Record 26 of Set 22 | sunrise manor
# Processing Record 27 of Set 22 | ilinge
# Processing Record 28 of Set 22 | brownsville
# Processing Record 29 of Set 22 | touros
# Processing Record 30 of Set 22 | dunedin
# Processing Record 31 of Set 22 | ixtapa
# Processing Record 32 of Set 22 | chekhov
# Processing Record 33 of Set 22 | portland
# Processing Record 34 of Set 22 | tosno
# Processing Record 35 of Set 22 | mineiros
# Processing Record 36 of Set 22 | vryburg
# Processing Record 37 of Set 22 | tashtagol
# Processing Record 38 of Set 22 | jinchang
# Processing Record 39 of Set 22 | tatawin
# Processing Record 40 of Set 22 | castrillon
# Processing Record 41 of Set 22 | sur
# Processing Record 42 of Set 22 | bom jesus
# Processing Record 43 of Set 22 | alofi
# Processing Record 44 of Set 22 | sept-iles
# Processing Record 45 of Set 22 | languyan
# Processing Record 46 of Set 22 | pacific grove
# Processing Record 47 of Set 22 | harlingen
# Processing Record 48 of Set 22 | henties bay
# Processing Record 49 of Set 22 | gaoual
# Processing Record 50 of Set 22 | nizhnevartovsk
# Processing Record 1 of Set 23 | wuda
# Processing Record 2 of Set 23 | la crosse
# Processing Record 3 of Set 23 | camalu
# Processing Record 4 of Set 23 | meulaboh
# Processing Record 5 of Set 23 | chara
# Processing Record 6 of Set 23 | palmas de monte alto
# Processing Record 7 of Set 23 | yanan
# City not found. Skipping...
# Processing Record 8 of Set 23 | brae
# Processing Record 9 of Set 23 | kantemirovka
# Processing Record 10 of Set 23 | ushtobe
# Processing Record 11 of Set 23 | abiy adi
# City not found. Skipping...
# Processing Record 12 of Set 23 | savinka
# Processing Record 13 of Set 23 | locri
# Processing Record 14 of Set 23 | lumeje
# Processing Record 15 of Set 23 | talcahuano
# Processing Record 16 of Set 23 | redmond
# Processing Record 17 of Set 23 | oranjestad
# Processing Record 18 of Set 23 | trinidad
# Processing Record 19 of Set 23 | gari
# Processing Record 20 of Set 23 | vao
# Processing Record 21 of Set 23 | soyo
# Processing Record 22 of Set 23 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 23 | berdychiv
# Processing Record 24 of Set 23 | palembang
# Processing Record 25 of Set 23 | neiafu
# Processing Record 26 of Set 23 | beloha
# Processing Record 27 of Set 23 | tarko-sale
# Processing Record 28 of Set 23 | tequila
# Processing Record 29 of Set 23 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 23 | japura
# Processing Record 31 of Set 23 | katsuura
# Processing Record 32 of Set 23 | banda aceh
# Processing Record 33 of Set 23 | north bend
# Processing Record 34 of Set 23 | birjand
# Processing Record 35 of Set 23 | middle island
# Processing Record 36 of Set 23 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 23 | luwero
# Processing Record 38 of Set 23 | tougan
# Processing Record 39 of Set 23 | springdale
# Processing Record 40 of Set 23 | pevek
# Processing Record 41 of Set 23 | mersing
# Processing Record 42 of Set 23 | awjilah
# Processing Record 43 of Set 23 | palmer
# Processing Record 44 of Set 23 | namwala
# Processing Record 45 of Set 23 | leshukonskoye
# Processing Record 46 of Set 23 | sabang
# Processing Record 47 of Set 23 | pavlohrad
# Processing Record 48 of Set 23 | beloeil
# Processing Record 49 of Set 23 | laukaa
# Processing Record 50 of Set 23 | bolshaya sosnova
# Processing Record 1 of Set 24 | port lincoln
# Processing Record 2 of Set 24 | saint-joseph
# Processing Record 3 of Set 24 | arlit
# Processing Record 4 of Set 24 | arequipa
# Processing Record 5 of Set 24 | mazara del vallo
# Processing Record 6 of Set 24 | la paz
# Processing Record 7 of Set 24 | howard springs
# Processing Record 8 of Set 24 | maniitsoq
# Processing Record 9 of Set 24 | camacupa
# Processing Record 10 of Set 24 | itoman
# Processing Record 11 of Set 24 | cumaribo
# City not found. Skipping...
# Processing Record 12 of Set 24 | quartucciu
# Processing Record 13 of Set 24 | la peca
# Processing Record 14 of Set 24 | tapejara
# Processing Record 15 of Set 24 | noumea
# Processing Record 16 of Set 24 | saint anthony
# Processing Record 17 of Set 24 | weihe
# Processing Record 18 of Set 24 | sinnamary
# Processing Record 19 of Set 24 | havre-saint-pierre
# Processing Record 20 of Set 24 | lithgow
# Processing Record 21 of Set 24 | khorramshahr
# Processing Record 22 of Set 24 | suntar
# Processing Record 23 of Set 24 | marzuq
# Processing Record 24 of Set 24 | airai
# Processing Record 25 of Set 24 | holsted
# Processing Record 26 of Set 24 | seduva
# Processing Record 27 of Set 24 | misratah
# Processing Record 28 of Set 24 | sergeyevka
# Processing Record 29 of Set 24 | praia
# Processing Record 30 of Set 24 | rrogozhine
# Processing Record 31 of Set 24 | pochutla
# Processing Record 32 of Set 24 | jiayuguan
# Processing Record 33 of Set 24 | salas
# Processing Record 34 of Set 24 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 24 | uray
# Processing Record 36 of Set 24 | mayo
# Processing Record 37 of Set 24 | penzance
# Processing Record 38 of Set 24 | antalaha
# Processing Record 39 of Set 24 | lake havasu city
# Processing Record 40 of Set 24 | edson
# Processing Record 41 of Set 24 | northam
# Processing Record 42 of Set 24 | sinaloa
# Processing Record 43 of Set 24 | leningradskiy
# Processing Record 44 of Set 24 | luang prabang
# Processing Record 45 of Set 24 | ikwiriri
# Processing Record 46 of Set 24 | am timan
# Processing Record 47 of Set 24 | farah
# Processing Record 48 of Set 24 | morros
# Processing Record 49 of Set 24 | rudnogorsk
# Processing Record 50 of Set 24 | constantine
# Processing Record 1 of Set 25 | khandyga
# Processing Record 2 of Set 25 | margate
# Processing Record 3 of Set 25 | rafraf
# Processing Record 4 of Set 25 | abu zabad
# Processing Record 5 of Set 25 | beyneu
# Processing Record 6 of Set 25 | shiyan
# Processing Record 7 of Set 25 | chute-aux-outardes
# Processing Record 8 of Set 25 | kroya
# Processing Record 9 of Set 25 | coihaique
# Processing Record 10 of Set 25 | coquimbo
# Processing Record 11 of Set 25 | maldonado
# Processing Record 12 of Set 25 | kamenka
# Processing Record 13 of Set 25 | burnie
# Processing Record 14 of Set 25 | faanui
# Processing Record 15 of Set 25 | viransehir
# Processing Record 16 of Set 25 | honningsvag
# Processing Record 17 of Set 25 | kokopo
# Processing Record 18 of Set 25 | zelenoborskiy
# Processing Record 19 of Set 25 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 25 | garchitorena
# Processing Record 21 of Set 25 | valley
# Processing Record 22 of Set 25 | caliling
# Processing Record 23 of Set 25 | aklavik
# Processing Record 24 of Set 25 | eureka
# Processing Record 25 of Set 25 | peruibe
# Processing Record 26 of Set 25 | namatanai
# Processing Record 27 of Set 25 | vila velha
# Processing Record 28 of Set 25 | westport
# Processing Record 29 of Set 25 | san cristobal
# Processing Record 30 of Set 25 | mankachar
# Processing Record 31 of Set 25 | montepuez
# Processing Record 32 of Set 25 | pringsewu
# Processing Record 33 of Set 25 | mikhaylovsk
# Processing Record 34 of Set 25 | itarema
# Processing Record 35 of Set 25 | escanaba
# Processing Record 36 of Set 25 | kenai
# Processing Record 37 of Set 25 | san patricio
# Processing Record 38 of Set 25 | mildura
# Processing Record 39 of Set 25 | afua
# Processing Record 40 of Set 25 | poso
# Processing Record 41 of Set 25 | lufilufi
# Processing Record 42 of Set 25 | soe
# Processing Record 43 of Set 25 | la maddalena
# Processing Record 44 of Set 25 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 25 | murchison
# Processing Record 46 of Set 25 | port-cartier
# Processing Record 47 of Set 25 | vestmanna
# Processing Record 48 of Set 25 | khormuj
# City not found. Skipping...
# Processing Record 49 of Set 25 | moose factory
# Processing Record 50 of Set 25 | pervomayskiy
# Processing Record 1 of Set 26 | pangnirtung
# Processing Record 2 of Set 26 | mokobeng
# Processing Record 3 of Set 26 | bundaberg
# Processing Record 4 of Set 26 | moche
# Processing Record 5 of Set 26 | solnechnyy
# Processing Record 6 of Set 26 | quito
# Processing Record 7 of Set 26 | jennings
# Processing Record 8 of Set 26 | monrovia
# Processing Record 9 of Set 26 | novaya ladoga
# Processing Record 10 of Set 26 | sao gotardo
# Processing Record 11 of Set 26 | ust-ishim
# Processing Record 12 of Set 26 | marquette
# Processing Record 13 of Set 26 | sterling
# Processing Record 14 of Set 26 | kinango
# Processing Record 15 of Set 26 | sao miguel do araguaia
# Processing Record 16 of Set 26 | port-gentil
# Processing Record 17 of Set 26 | valuyki
# Processing Record 18 of Set 26 | ancud
# Processing Record 19 of Set 26 | nioro
# Processing Record 20 of Set 26 | goulburn
# Processing Record 21 of Set 26 | merta
# Processing Record 22 of Set 26 | ketchikan
# Processing Record 23 of Set 26 | wanaka
# Processing Record 24 of Set 26 | rivadavia
# Processing Record 25 of Set 26 | galveston
# Processing Record 26 of Set 26 | wilmington
# Processing Record 27 of Set 26 | myskhako
# Processing Record 28 of Set 26 | poltavka
# Processing Record 29 of Set 26 | gat
# Processing Record 30 of Set 26 | geraldton
# Processing Record 31 of Set 26 | cheney
# Processing Record 32 of Set 26 | san pedro
# Processing Record 33 of Set 26 | russell
# Processing Record 34 of Set 26 | ouargaye
# Processing Record 35 of Set 26 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 26 | copala
# Processing Record 37 of Set 26 | karasjok
# Processing Record 38 of Set 26 | lobva
# Processing Record 39 of Set 26 | namibe
# Processing Record 40 of Set 26 | yumen
# Processing Record 41 of Set 26 | vieques
# Processing Record 42 of Set 26 | kindu
# Processing Record 43 of Set 26 | sao filipe
# Processing Record 44 of Set 26 | san quintin
# Processing Record 45 of Set 26 | broome
# Processing Record 46 of Set 26 | upington
# Processing Record 47 of Set 26 | lerwick
# Processing Record 48 of Set 26 | cabedelo
# Processing Record 49 of Set 26 | lahij
# Processing Record 50 of Set 26 | dergachi
# Processing Record 1 of Set 27 | kadoma
# Processing Record 2 of Set 27 | shintomi
# Processing Record 3 of Set 27 | scarborough
# Processing Record 4 of Set 27 | digby
# Processing Record 5 of Set 27 | lata
# Processing Record 6 of Set 27 | taburi
# City not found. Skipping...
# Processing Record 7 of Set 27 | punta cardon
# Processing Record 8 of Set 27 | qaqortoq
# Processing Record 9 of Set 27 | aksu
# Processing Record 10 of Set 27 | phangnga
# Processing Record 11 of Set 27 | lar gerd
# City not found. Skipping...
# Processing Record 12 of Set 27 | hay river
# Processing Record 13 of Set 27 | tabialan
# City not found. Skipping...
# Processing Record 14 of Set 27 | kraslava
# Processing Record 15 of Set 27 | tay ninh
# Processing Record 16 of Set 27 | mogadishu
# Processing Record 17 of Set 27 | zlobin
# Processing Record 18 of Set 27 | alice springs
# Processing Record 19 of Set 27 | warrington
# Processing Record 20 of Set 27 | madera
# Processing Record 21 of Set 27 | babanusah
# City not found. Skipping...
# Processing Record 22 of Set 27 | tome-acu
# City not found. Skipping...
# Processing Record 23 of Set 27 | beidao
# Processing Record 24 of Set 27 | devonport
# Processing Record 25 of Set 27 | dong xoai
# Processing Record 26 of Set 27 | jurado
# Processing Record 27 of Set 27 | kihei
# Processing Record 28 of Set 27 | dvinskoy
# Processing Record 29 of Set 27 | marsaxlokk
# Processing Record 30 of Set 27 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 31 of Set 27 | kushima
# Processing Record 32 of Set 27 | zalantun
# Processing Record 33 of Set 27 | thunder bay
# Processing Record 34 of Set 27 | puerto del rosario
# Processing Record 35 of Set 27 | zhigalovo
# Processing Record 36 of Set 27 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 27 | middletown
# Processing Record 38 of Set 27 | mikuni
# Processing Record 39 of Set 27 | ust-maya
# Processing Record 40 of Set 27 | imperia
# Processing Record 41 of Set 27 | sao carlos
# Processing Record 42 of Set 27 | birin
# Processing Record 43 of Set 27 | muyuka
# Processing Record 44 of Set 27 | noyabrsk
# Processing Record 45 of Set 27 | spirit river
# Processing Record 46 of Set 27 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 27 | surin
# Processing Record 48 of Set 27 | pokhara
# Processing Record 49 of Set 27 | kashan
# Processing Record 50 of Set 27 | hargeysa
# Processing Record 1 of Set 28 | antofagasta
# Processing Record 2 of Set 28 | natal
# Processing Record 3 of Set 28 | jiddah
# City not found. Skipping...
# Processing Record 4 of Set 28 | victoria
# Processing Record 5 of Set 28 | vangaindrano
# Processing Record 6 of Set 28 | chengde
# Processing Record 7 of Set 28 | plymouth
# Processing Record 8 of Set 28 | general roca
# Processing Record 9 of Set 28 | chitral
# Processing Record 10 of Set 28 | ituacu
# Processing Record 11 of Set 28 | kosino
# Processing Record 12 of Set 28 | tumarbong
# Processing Record 13 of Set 28 | konstantinovka
# Processing Record 14 of Set 28 | grindavik
# Processing Record 15 of Set 28 | egvekinot
# Processing Record 16 of Set 28 | saucillo
# Processing Record 17 of Set 28 | alenquer
# Processing Record 18 of Set 28 | shakawe
# Processing Record 19 of Set 28 | killybegs
# Processing Record 20 of Set 28 | severomuysk
# Processing Record 21 of Set 28 | avera
# Processing Record 22 of Set 28 | ibaiti
# Processing Record 23 of Set 28 | san luis
# Processing Record 24 of Set 28 | ye
# City not found. Skipping...
# Processing Record 25 of Set 28 | araguatins
# City not found. Skipping...
# Processing Record 26 of Set 28 | constitucion
# Processing Record 27 of Set 28 | marienburg
# Processing Record 28 of Set 28 | port macquarie
# Processing Record 29 of Set 28 | safita
# Processing Record 30 of Set 28 | albenga
# Processing Record 31 of Set 28 | pelotas
# Processing Record 32 of Set 28 | rohnert park
# Processing Record 33 of Set 28 | gobabis
# Processing Record 34 of Set 28 | jijiga
# Processing Record 35 of Set 28 | samarinda
# Processing Record 36 of Set 28 | sangueya
# Processing Record 37 of Set 28 | gwadar
# Processing Record 38 of Set 28 | pachino
# Processing Record 39 of Set 28 | solosolo
# Processing Record 40 of Set 28 | ca mau
# Processing Record 41 of Set 28 | chicama
# Processing Record 42 of Set 28 | nevel
# Processing Record 43 of Set 28 | pahrump
# Processing Record 44 of Set 28 | kuruman
# Processing Record 45 of Set 28 | mount gambier
# Processing Record 46 of Set 28 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 47 of Set 28 | mafinga
# Processing Record 48 of Set 28 | santa maria da vitoria
# Processing Record 49 of Set 28 | hofn
# Processing Record 50 of Set 28 | cobija
# Processing Record 1 of Set 29 | freeport
# Processing Record 2 of Set 29 | esna
# Processing Record 3 of Set 29 | aripuana
# Processing Record 4 of Set 29 | nagato
# Processing Record 5 of Set 29 | wanxian
# Processing Record 6 of Set 29 | kem
# Processing Record 7 of Set 29 | okato
# Processing Record 8 of Set 29 | kaupanger
# Processing Record 9 of Set 29 | cape canaveral
# Processing Record 10 of Set 29 | talnakh
# Processing Record 11 of Set 29 | hami
# Processing Record 12 of Set 29 | yar-sale
# Processing Record 13 of Set 29 | ahja
# Processing Record 14 of Set 29 | kuvshinovo
# Processing Record 15 of Set 29 | midland
# Processing Record 16 of Set 29 | moree
# Processing Record 17 of Set 29 | casino
# Processing Record 18 of Set 29 | moranbah
# Processing Record 19 of Set 29 | gazojak
# Processing Record 20 of Set 29 | los altos
# Processing Record 21 of Set 29 | dwarka
# Processing Record 22 of Set 29 | ugoofaaru
# Processing Record 23 of Set 29 | yabelo
# Processing Record 24 of Set 29 | sechura
# Processing Record 25 of Set 29 | juneau
# Processing Record 26 of Set 29 | phayuha khiri
# Processing Record 27 of Set 29 | vanimo
# Processing Record 28 of Set 29 | gladstone
# Processing Record 29 of Set 29 | gulshat
# City not found. Skipping...
# Processing Record 30 of Set 29 | abu samrah
# Processing Record 31 of Set 29 | swinoujscie
# Processing Record 32 of Set 29 | tawnat
# City not found. Skipping...
# Processing Record 33 of Set 29 | rovaniemi
# Processing Record 34 of Set 29 | wheatley
# Processing Record 35 of Set 29 | puerto madryn
# Processing Record 36 of Set 29 | najran
# Processing Record 37 of Set 29 | ereymentau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bulawayo -20.1500   28.5833     55.44        68          62
# 1            Poum -20.2333  164.0167     79.23        71         100
# 2       Upernavik  72.7868  -56.1549      2.28        72         100
# 3            Chuy -33.6971  -53.4616     61.86        76          98
# 4       Hithadhoo  -0.6000   73.0833     83.79        76         100
# 5         Kitsuki  33.4167  131.6167     57.20        67          75
# 6        Khatanga  71.9667  102.5000    -27.22        95          36
# 7         Sorland  67.6670   12.6934     39.15        74         100
# 8  Ribeira Grande  38.5167  -28.7000     57.81        66           0
# 9          Barrow  71.2906 -156.7887     -4.00        59           1
#
#    Wind Speed Weather description
# 0        4.90       broken clouds
# 1        9.28     overcast clouds
# 2        5.50     overcast clouds
# 3        6.58     overcast clouds
# 4       19.95     overcast clouds
# 5       11.50       broken clouds
# 6        0.51    scattered clouds
# 7       21.32     overcast clouds
# 8       10.71           clear sky
# 9       23.02           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
