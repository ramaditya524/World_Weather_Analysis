# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
country = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    country_code = citipy.nearest_city(coordinate[0], coordinate[1]).country_code

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        country.append(country_code)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
city_url = url + "&q=" + "vrangel"
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': 133.0839, 'lat': 42.7297},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 48.74,
#   'feels_like': 47.26,
#   'temp_min': 48.74,
#   'temp_max': 48.74,
#   'pressure': 1025,
#   'humidity': 52,
#   'sea_level': 1025,
#   'grnd_level': 1023},
#  'visibility': 10000,
#  'wind': {'speed': 4.21, 'deg': 268, 'gust': 7.09},
#  'clouds': {'all': 0},
#  'dt': 1617245254,
#  'sys': {'country': 'RU', 'sunrise': 1617223818, 'sunset': 1617269556},
#  'timezone': 36000,
#  'id': 2013258,
#  'name': "Vrangel'",
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": country[i],
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather description":city_weather_desc})
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 1 | algiers
# Processing Record 4 of Set 1 | batie
# Processing Record 5 of Set 1 | port macquarie
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | narsaq
# Processing Record 8 of Set 1 | sao filipe
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | makakilo city
# Processing Record 13 of Set 1 | yatou
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | catuday
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | kasulu
# Processing Record 20 of Set 1 | longyearbyen
# Processing Record 21 of Set 1 | clyde river
# Processing Record 22 of Set 1 | pangnirtung
# Processing Record 23 of Set 1 | cidreira
# Processing Record 24 of Set 1 | yerbogachen
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | luganville
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | pisco
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | chishtian mandi
# Processing Record 34 of Set 1 | nhulunbuy
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | san luis
# Processing Record 38 of Set 1 | namibe
# Processing Record 39 of Set 1 | cayenne
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | marsh harbour
# Processing Record 42 of Set 1 | bainbridge
# Processing Record 43 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | ada
# Processing Record 49 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | dingle
# Processing Record 3 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 2 | saint-augustin
# Processing Record 5 of Set 2 | san quintin
# Processing Record 6 of Set 2 | lebu
# Processing Record 7 of Set 2 | talnakh
# Processing Record 8 of Set 2 | lazurne
# Processing Record 9 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 2 | rawson
# Processing Record 11 of Set 2 | shintomi
# Processing Record 12 of Set 2 | hinton
# Processing Record 13 of Set 2 | luderitz
# Processing Record 14 of Set 2 | bowen
# Processing Record 15 of Set 2 | avarua
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | tyukhtet
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | san carlos de bariloche
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | madimba
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | kiknur
# Processing Record 24 of Set 2 | moussoro
# Processing Record 25 of Set 2 | xilitla
# Processing Record 26 of Set 2 | tailai
# Processing Record 27 of Set 2 | severo-kurilsk
# Processing Record 28 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 2 | rovaniemi
# Processing Record 30 of Set 2 | brooks
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | yar-sale
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | tarata
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | marihatag
# Processing Record 37 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 2 | live oak
# Processing Record 39 of Set 2 | bhander
# Processing Record 40 of Set 2 | sainte-marie
# Processing Record 41 of Set 2 | muroto
# Processing Record 42 of Set 2 | lorengau
# Processing Record 43 of Set 2 | tuatapere
# Processing Record 44 of Set 2 | saskylakh
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | bolshaya atnya
# City not found. Skipping...
# Processing Record 47 of Set 2 | saint george
# Processing Record 48 of Set 2 | bredasdorp
# Processing Record 49 of Set 2 | ixtapa
# Processing Record 50 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 1 of Set 3 | constantine
# Processing Record 2 of Set 3 | kleck
# City not found. Skipping...
# Processing Record 3 of Set 3 | voh
# Processing Record 4 of Set 3 | klaksvik
# Processing Record 5 of Set 3 | portland
# Processing Record 6 of Set 3 | taoudenni
# Processing Record 7 of Set 3 | zhovti vody
# Processing Record 8 of Set 3 | margate
# Processing Record 9 of Set 3 | alta floresta
# Processing Record 10 of Set 3 | turka
# Processing Record 11 of Set 3 | tadpatri
# Processing Record 12 of Set 3 | beringovskiy
# Processing Record 13 of Set 3 | chany
# Processing Record 14 of Set 3 | minuri
# Processing Record 15 of Set 3 | carnarvon
# Processing Record 16 of Set 3 | rio grande
# Processing Record 17 of Set 3 | mulki
# Processing Record 18 of Set 3 | georgetown
# Processing Record 19 of Set 3 | chadan
# Processing Record 20 of Set 3 | bubaque
# Processing Record 21 of Set 3 | tahta
# Processing Record 22 of Set 3 | vernon
# Processing Record 23 of Set 3 | tasiilaq
# Processing Record 24 of Set 3 | geraldton
# Processing Record 25 of Set 3 | broken hill
# Processing Record 26 of Set 3 | sao jose da coroa grande
# Processing Record 27 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 3 | iquitos
# Processing Record 29 of Set 3 | vardo
# Processing Record 30 of Set 3 | matara
# Processing Record 31 of Set 3 | coahuayana
# Processing Record 32 of Set 3 | chake chake
# Processing Record 33 of Set 3 | changji
# Processing Record 34 of Set 3 | khatanga
# Processing Record 35 of Set 3 | norman wells
# Processing Record 36 of Set 3 | maloy
# Processing Record 37 of Set 3 | cap malheureux
# Processing Record 38 of Set 3 | padang
# Processing Record 39 of Set 3 | huarmey
# Processing Record 40 of Set 3 | tiksi
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | touros
# Processing Record 43 of Set 3 | dakar
# Processing Record 44 of Set 3 | bluff
# Processing Record 45 of Set 3 | thinadhoo
# Processing Record 46 of Set 3 | lubana
# Processing Record 47 of Set 3 | skjervoy
# Processing Record 48 of Set 3 | shubarkuduk
# Processing Record 49 of Set 3 | cabra
# Processing Record 50 of Set 3 | kirakira
# Processing Record 1 of Set 4 | fairbanks
# Processing Record 2 of Set 4 | rio gallegos
# Processing Record 3 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 4 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 4 | chissamba
# Processing Record 6 of Set 4 | tabuk
# Processing Record 7 of Set 4 | el alto
# Processing Record 8 of Set 4 | thompson
# Processing Record 9 of Set 4 | oktyabrskiy
# Processing Record 10 of Set 4 | santa lucia
# Processing Record 11 of Set 4 | togur
# Processing Record 12 of Set 4 | itacare
# Processing Record 13 of Set 4 | plettenberg bay
# Processing Record 14 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 4 | katsuura
# Processing Record 16 of Set 4 | sur
# Processing Record 17 of Set 4 | nome
# Processing Record 18 of Set 4 | nishihara
# Processing Record 19 of Set 4 | asau
# Processing Record 20 of Set 4 | hovd
# Processing Record 21 of Set 4 | aqtobe
# Processing Record 22 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 24 of Set 4 | guerrero negro
# Processing Record 25 of Set 4 | vila velha
# Processing Record 26 of Set 4 | poya
# Processing Record 27 of Set 4 | aykhal
# Processing Record 28 of Set 4 | mahebourg
# Processing Record 29 of Set 4 | ilinskiy
# Processing Record 30 of Set 4 | dikson
# Processing Record 31 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 4 | yulara
# Processing Record 33 of Set 4 | tolaga bay
# Processing Record 34 of Set 4 | egvekinot
# Processing Record 35 of Set 4 | lavrentiya
# Processing Record 36 of Set 4 | omsukchan
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | flinders
# Processing Record 39 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 4 | nakatsu
# Processing Record 41 of Set 4 | cabo san lucas
# Processing Record 42 of Set 4 | purpe
# Processing Record 43 of Set 4 | general pico
# Processing Record 44 of Set 4 | dordrecht
# Processing Record 45 of Set 4 | morant bay
# Processing Record 46 of Set 4 | adrar
# Processing Record 47 of Set 4 | birin
# Processing Record 48 of Set 4 | bengkulu
# Processing Record 49 of Set 4 | ostrovnoy
# Processing Record 50 of Set 4 | basyanovskiy
# City not found. Skipping...
# Processing Record 1 of Set 5 | akyab
# Processing Record 2 of Set 5 | shirokiy
# Processing Record 3 of Set 5 | boguchany
# Processing Record 4 of Set 5 | mastung
# Processing Record 5 of Set 5 | talawdi
# City not found. Skipping...
# Processing Record 6 of Set 5 | fort-shevchenko
# Processing Record 7 of Set 5 | balikpapan
# Processing Record 8 of Set 5 | lima
# Processing Record 9 of Set 5 | ribeira grande
# Processing Record 10 of Set 5 | fortuna
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | vicente guerrero
# Processing Record 13 of Set 5 | marsa matruh
# Processing Record 14 of Set 5 | kapaa
# Processing Record 15 of Set 5 | verkh-usugli
# Processing Record 16 of Set 5 | ternate
# Processing Record 17 of Set 5 | onega
# Processing Record 18 of Set 5 | areosa
# Processing Record 19 of Set 5 | codrington
# Processing Record 20 of Set 5 | coquimbo
# Processing Record 21 of Set 5 | sorland
# Processing Record 22 of Set 5 | bethel
# Processing Record 23 of Set 5 | iqaluit
# Processing Record 24 of Set 5 | dauphin
# Processing Record 25 of Set 5 | ulaangom
# Processing Record 26 of Set 5 | grand gaube
# Processing Record 27 of Set 5 | svetlogorsk
# Processing Record 28 of Set 5 | nagar karnul
# Processing Record 29 of Set 5 | buchanan
# Processing Record 30 of Set 5 | sitka
# Processing Record 31 of Set 5 | itarema
# Processing Record 32 of Set 5 | port hardy
# Processing Record 33 of Set 5 | east london
# Processing Record 34 of Set 5 | ancud
# Processing Record 35 of Set 5 | makat
# Processing Record 36 of Set 5 | castro
# Processing Record 37 of Set 5 | ilo
# Processing Record 38 of Set 5 | pushkinskiye gory
# Processing Record 39 of Set 5 | los llanos de aridane
# Processing Record 40 of Set 5 | wanning
# Processing Record 41 of Set 5 | pangkalanbuun
# Processing Record 42 of Set 5 | porto santo
# Processing Record 43 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 5 | kieta
# Processing Record 45 of Set 5 | verkhnyaya inta
# Processing Record 46 of Set 5 | esperance
# Processing Record 47 of Set 5 | upernavik
# Processing Record 48 of Set 5 | dalvik
# Processing Record 49 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 5 | kassala
# Processing Record 1 of Set 6 | christchurch
# Processing Record 2 of Set 6 | laguna
# Processing Record 3 of Set 6 | rio tercero
# Processing Record 4 of Set 6 | birjand
# Processing Record 5 of Set 6 | svobodnyy
# Processing Record 6 of Set 6 | opunake
# Processing Record 7 of Set 6 | kenora
# Processing Record 8 of Set 6 | balkanabat
# Processing Record 9 of Set 6 | kaeo
# Processing Record 10 of Set 6 | pala
# Processing Record 11 of Set 6 | vila franca do campo
# Processing Record 12 of Set 6 | kumluca
# Processing Record 13 of Set 6 | farap
# Processing Record 14 of Set 6 | beloha
# Processing Record 15 of Set 6 | umea
# Processing Record 16 of Set 6 | la sarre
# Processing Record 17 of Set 6 | leshan
# Processing Record 18 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 19 of Set 6 | along
# Processing Record 20 of Set 6 | do gonbadan
# Processing Record 21 of Set 6 | avera
# Processing Record 22 of Set 6 | pevek
# Processing Record 23 of Set 6 | calabozo
# Processing Record 24 of Set 6 | kavieng
# Processing Record 25 of Set 6 | pitimbu
# Processing Record 26 of Set 6 | lac du bonnet
# Processing Record 27 of Set 6 | boysun
# Processing Record 28 of Set 6 | alice springs
# Processing Record 29 of Set 6 | boyolangu
# Processing Record 30 of Set 6 | atambua
# Processing Record 31 of Set 6 | sirjan
# Processing Record 32 of Set 6 | kahului
# Processing Record 33 of Set 6 | kostomuksha
# Processing Record 34 of Set 6 | betioky
# Processing Record 35 of Set 6 | jalu
# Processing Record 36 of Set 6 | shumskiy
# Processing Record 37 of Set 6 | vao
# Processing Record 38 of Set 6 | springbok
# Processing Record 39 of Set 6 | chernyshevskiy
# Processing Record 40 of Set 6 | hasaki
# Processing Record 41 of Set 6 | linjiang
# Processing Record 42 of Set 6 | ranong
# Processing Record 43 of Set 6 | tadine
# Processing Record 44 of Set 6 | north bend
# Processing Record 45 of Set 6 | paamiut
# Processing Record 46 of Set 6 | naze
# Processing Record 47 of Set 6 | usinsk
# Processing Record 48 of Set 6 | taksimo
# Processing Record 49 of Set 6 | bereda
# Processing Record 50 of Set 6 | itoman
# Processing Record 1 of Set 7 | ponta do sol
# Processing Record 2 of Set 7 | shimoda
# Processing Record 3 of Set 7 | faya
# Processing Record 4 of Set 7 | kilmez
# City not found. Skipping...
# Processing Record 5 of Set 7 | ilulissat
# Processing Record 6 of Set 7 | kavaratti
# Processing Record 7 of Set 7 | turkmenabat
# Processing Record 8 of Set 7 | paracuru
# Processing Record 9 of Set 7 | bathsheba
# Processing Record 10 of Set 7 | mount isa
# Processing Record 11 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 7 | ginda
# Processing Record 13 of Set 7 | borba
# Processing Record 14 of Set 7 | sayyan
# Processing Record 15 of Set 7 | raudeberg
# Processing Record 16 of Set 7 | oudtshoorn
# Processing Record 17 of Set 7 | shingu
# Processing Record 18 of Set 7 | viedma
# Processing Record 19 of Set 7 | labuhan
# Processing Record 20 of Set 7 | okhotsk
# Processing Record 21 of Set 7 | puerto ayacucho
# Processing Record 22 of Set 7 | lesnoy
# Processing Record 23 of Set 7 | champerico
# Processing Record 24 of Set 7 | ekibastuz
# Processing Record 25 of Set 7 | kudahuvadhoo
# Processing Record 26 of Set 7 | yithion
# City not found. Skipping...
# Processing Record 27 of Set 7 | gariaband
# Processing Record 28 of Set 7 | zhigansk
# Processing Record 29 of Set 7 | luau
# Processing Record 30 of Set 7 | baculin
# Processing Record 31 of Set 7 | cosmesti
# Processing Record 32 of Set 7 | port lincoln
# Processing Record 33 of Set 7 | greytown
# Processing Record 34 of Set 7 | morehead
# Processing Record 35 of Set 7 | port blair
# Processing Record 36 of Set 7 | manggar
# Processing Record 37 of Set 7 | mayo
# Processing Record 38 of Set 7 | lata
# Processing Record 39 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 40 of Set 7 | honiara
# Processing Record 41 of Set 7 | deputatskiy
# Processing Record 42 of Set 7 | warri
# Processing Record 43 of Set 7 | trelleborg
# Processing Record 44 of Set 7 | urumqi
# Processing Record 45 of Set 7 | smithers
# Processing Record 46 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 7 | bambous virieux
# Processing Record 48 of Set 7 | yabrud
# Processing Record 49 of Set 7 | meulaboh
# Processing Record 50 of Set 7 | san cristobal
# Processing Record 1 of Set 8 | lake charles
# Processing Record 2 of Set 8 | gat
# Processing Record 3 of Set 8 | seoul
# Processing Record 4 of Set 8 | coos bay
# Processing Record 5 of Set 8 | okha
# Processing Record 6 of Set 8 | san juan
# Processing Record 7 of Set 8 | port said
# Processing Record 8 of Set 8 | tapaua
# City not found. Skipping...
# Processing Record 9 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 8 | leeton
# Processing Record 11 of Set 8 | college
# Processing Record 12 of Set 8 | abu samrah
# Processing Record 13 of Set 8 | san pedro
# Processing Record 14 of Set 8 | adre
# Processing Record 15 of Set 8 | vestmannaeyjar
# Processing Record 16 of Set 8 | cairns
# Processing Record 17 of Set 8 | metehara
# City not found. Skipping...
# Processing Record 18 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 8 | quatre cocos
# Processing Record 20 of Set 8 | constitucion
# Processing Record 21 of Set 8 | bundaberg
# Processing Record 22 of Set 8 | mar del plata
# Processing Record 23 of Set 8 | gouyave
# Processing Record 24 of Set 8 | kondopoga
# Processing Record 25 of Set 8 | hobyo
# Processing Record 26 of Set 8 | muisne
# Processing Record 27 of Set 8 | salalah
# Processing Record 28 of Set 8 | khonsa
# Processing Record 29 of Set 8 | sao joao da barra
# Processing Record 30 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 31 of Set 8 | ulagan
# Processing Record 32 of Set 8 | broome
# Processing Record 33 of Set 8 | junin
# Processing Record 34 of Set 8 | ozinki
# Processing Record 35 of Set 8 | haifa
# Processing Record 36 of Set 8 | bandarbeyla
# Processing Record 37 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 38 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 8 | maltahohe
# Processing Record 40 of Set 8 | carballo
# Processing Record 41 of Set 8 | lompoc
# Processing Record 42 of Set 8 | wahiawa
# Processing Record 43 of Set 8 | lixourion
# Processing Record 44 of Set 8 | souillac
# Processing Record 45 of Set 8 | diu
# Processing Record 46 of Set 8 | dickinson
# Processing Record 47 of Set 8 | chumphon
# Processing Record 48 of Set 8 | provost
# Processing Record 49 of Set 8 | sa kaeo
# Processing Record 50 of Set 8 | goderich
# Processing Record 1 of Set 9 | tura
# Processing Record 2 of Set 9 | saint-pierre
# Processing Record 3 of Set 9 | verkhoyansk
# Processing Record 4 of Set 9 | gilgit
# Processing Record 5 of Set 9 | aklavik
# Processing Record 6 of Set 9 | tabarqah
# City not found. Skipping...
# Processing Record 7 of Set 9 | ewa beach
# Processing Record 8 of Set 9 | muros
# Processing Record 9 of Set 9 | kruisfontein
# Processing Record 10 of Set 9 | bilibino
# Processing Record 11 of Set 9 | hamilton
# Processing Record 12 of Set 9 | ouallam
# Processing Record 13 of Set 9 | netrakona
# Processing Record 14 of Set 9 | archidona
# Processing Record 15 of Set 9 | palmer
# Processing Record 16 of Set 9 | isangel
# Processing Record 17 of Set 9 | doha
# Processing Record 18 of Set 9 | woodstock
# Processing Record 19 of Set 9 | businga
# Processing Record 20 of Set 9 | galesong
# Processing Record 21 of Set 9 | kericho
# Processing Record 22 of Set 9 | gewane
# Processing Record 23 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 24 of Set 9 | meiktila
# Processing Record 25 of Set 9 | teguldet
# Processing Record 26 of Set 9 | silver city
# Processing Record 27 of Set 9 | mount pleasant
# Processing Record 28 of Set 9 | hualmay
# Processing Record 29 of Set 9 | zolotkovo
# Processing Record 30 of Set 9 | puerto madryn
# Processing Record 31 of Set 9 | brae
# Processing Record 32 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 33 of Set 9 | qasigiannguit
# Processing Record 34 of Set 9 | deyang
# Processing Record 35 of Set 9 | kundiawa
# Processing Record 36 of Set 9 | sompeta
# Processing Record 37 of Set 9 | kisangani
# Processing Record 38 of Set 9 | riverton
# Processing Record 39 of Set 9 | saint anthony
# Processing Record 40 of Set 9 | spiez
# Processing Record 41 of Set 9 | olafsvik
# Processing Record 42 of Set 9 | bichura
# Processing Record 43 of Set 9 | porto novo
# Processing Record 44 of Set 9 | altay
# Processing Record 45 of Set 9 | kaohsiung
# Processing Record 46 of Set 9 | dengzhou
# Processing Record 47 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 9 | boden
# Processing Record 49 of Set 9 | buraydah
# Processing Record 50 of Set 9 | maues
# Processing Record 1 of Set 10 | koungheul
# Processing Record 2 of Set 10 | arsenyev
# Processing Record 3 of Set 10 | nanortalik
# Processing Record 4 of Set 10 | golovchino
# Processing Record 5 of Set 10 | hennenman
# Processing Record 6 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 7 of Set 10 | awjilah
# Processing Record 8 of Set 10 | altamira
# Processing Record 9 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 10 | safwah
# City not found. Skipping...
# Processing Record 11 of Set 10 | hambantota
# Processing Record 12 of Set 10 | tiznit
# Processing Record 13 of Set 10 | marzuq
# Processing Record 14 of Set 10 | luba
# Processing Record 15 of Set 10 | bac lieu
# Processing Record 16 of Set 10 | leningradskiy
# Processing Record 17 of Set 10 | victoria
# Processing Record 18 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 19 of Set 10 | seymchan
# Processing Record 20 of Set 10 | langsa
# Processing Record 21 of Set 10 | jablah
# Processing Record 22 of Set 10 | benguela
# Processing Record 23 of Set 10 | prince rupert
# Processing Record 24 of Set 10 | la ronge
# Processing Record 25 of Set 10 | liverpool
# Processing Record 26 of Set 10 | half moon bay
# Processing Record 27 of Set 10 | santa isabel do rio negro
# Processing Record 28 of Set 10 | miami
# Processing Record 29 of Set 10 | the valley
# Processing Record 30 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 31 of Set 10 | kochi
# Processing Record 32 of Set 10 | novokizhinginsk
# Processing Record 33 of Set 10 | presidente bernardes
# Processing Record 34 of Set 10 | buta
# Processing Record 35 of Set 10 | tshikapa
# Processing Record 36 of Set 10 | itaituba
# Processing Record 37 of Set 10 | kaupanger
# Processing Record 38 of Set 10 | alofi
# Processing Record 39 of Set 10 | praia
# Processing Record 40 of Set 10 | rocha
# Processing Record 41 of Set 10 | dongying
# Processing Record 42 of Set 10 | solnechnyy
# Processing Record 43 of Set 10 | cockburn town
# Processing Record 44 of Set 10 | tongren
# Processing Record 45 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 46 of Set 10 | enshi
# Processing Record 47 of Set 10 | stephenville
# Processing Record 48 of Set 10 | vuktyl
# Processing Record 49 of Set 10 | celestun
# Processing Record 50 of Set 10 | husavik
# Processing Record 1 of Set 11 | kijang
# Processing Record 2 of Set 11 | port hedland
# Processing Record 3 of Set 11 | komsomolskiy
# Processing Record 4 of Set 11 | mubende
# Processing Record 5 of Set 11 | ilan
# Processing Record 6 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 7 of Set 11 | gollere
# City not found. Skipping...
# Processing Record 8 of Set 11 | kitimat
# Processing Record 9 of Set 11 | adiake
# Processing Record 10 of Set 11 | peniche
# Processing Record 11 of Set 11 | mogok
# Processing Record 12 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 13 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 14 of Set 11 | san jose
# Processing Record 15 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 11 | atikokan
# Processing Record 17 of Set 11 | pedernales
# Processing Record 18 of Set 11 | milas
# Processing Record 19 of Set 11 | inirida
# Processing Record 20 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 21 of Set 11 | san vicente
# Processing Record 22 of Set 11 | zhezkazgan
# Processing Record 23 of Set 11 | nichinan
# Processing Record 24 of Set 11 | carutapera
# Processing Record 25 of Set 11 | borogontsy
# Processing Record 26 of Set 11 | melfort
# Processing Record 27 of Set 11 | cherskiy
# Processing Record 28 of Set 11 | abaete
# Processing Record 29 of Set 11 | ayagoz
# Processing Record 30 of Set 11 | kharp
# Processing Record 31 of Set 11 | zhuanghe
# Processing Record 32 of Set 11 | wanaka
# Processing Record 33 of Set 11 | nelson bay
# Processing Record 34 of Set 11 | nsanje
# Processing Record 35 of Set 11 | sao felix do xingu
# Processing Record 36 of Set 11 | dabakala
# Processing Record 37 of Set 11 | iquique
# Processing Record 38 of Set 11 | ulyanovsk
# Processing Record 39 of Set 11 | pochutla
# Processing Record 40 of Set 11 | shibetsu
# Processing Record 41 of Set 11 | beisfjord
# Processing Record 42 of Set 11 | mabaruma
# Processing Record 43 of Set 11 | mombetsu
# Processing Record 44 of Set 11 | odweyne
# Processing Record 45 of Set 11 | barra patuca
# Processing Record 46 of Set 11 | calabar
# Processing Record 47 of Set 11 | biak
# Processing Record 48 of Set 11 | beinasco
# Processing Record 49 of Set 11 | merauke
# Processing Record 50 of Set 11 | beyneu
# Processing Record 1 of Set 12 | shakhovskaya
# Processing Record 2 of Set 12 | dhidhdhoo
# Processing Record 3 of Set 12 | provideniya
# Processing Record 4 of Set 12 | uglovskoye
# Processing Record 5 of Set 12 | lagdo
# Processing Record 6 of Set 12 | mala
# Processing Record 7 of Set 12 | novikovo
# Processing Record 8 of Set 12 | babanka
# Processing Record 9 of Set 12 | senekal
# Processing Record 10 of Set 12 | canutama
# Processing Record 11 of Set 12 | whitehorse
# Processing Record 12 of Set 12 | lagoa
# Processing Record 13 of Set 12 | kununurra
# Processing Record 14 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 12 | srednekolymsk
# Processing Record 16 of Set 12 | kulhudhuffushi
# Processing Record 17 of Set 12 | talaya
# Processing Record 18 of Set 12 | te anau
# Processing Record 19 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 12 | tubinskiy
# Processing Record 21 of Set 12 | chingirlau
# Processing Record 22 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 23 of Set 12 | malanje
# Processing Record 24 of Set 12 | puerto colombia
# Processing Record 25 of Set 12 | ramasukha
# City not found. Skipping...
# Processing Record 26 of Set 12 | pramanta
# Processing Record 27 of Set 12 | sinnamary
# Processing Record 28 of Set 12 | la palma
# Processing Record 29 of Set 12 | chapais
# Processing Record 30 of Set 12 | mayor pablo lagerenza
# Processing Record 31 of Set 12 | coihaique
# Processing Record 32 of Set 12 | lerwick
# Processing Record 33 of Set 12 | tamandare
# Processing Record 34 of Set 12 | mehamn
# Processing Record 35 of Set 12 | pueblo nuevo
# Processing Record 36 of Set 12 | krasnoyarka
# Processing Record 37 of Set 12 | vanavara
# Processing Record 38 of Set 12 | inhambane
# Processing Record 39 of Set 12 | nguruka
# Processing Record 40 of Set 12 | marysville
# Processing Record 41 of Set 12 | sal rei
# Processing Record 42 of Set 12 | cape canaveral
# Processing Record 43 of Set 12 | chokwe
# Processing Record 44 of Set 12 | cruz alta
# Processing Record 45 of Set 12 | bonavista
# Processing Record 46 of Set 12 | dudinka
# Processing Record 47 of Set 12 | waingapu
# Processing Record 48 of Set 12 | nemuro
# Processing Record 49 of Set 12 | saint-denis
# Processing Record 50 of Set 12 | riyadh
# Processing Record 1 of Set 13 | uruzgan
# Processing Record 2 of Set 13 | sabang
# Processing Record 3 of Set 13 | alyangula
# Processing Record 4 of Set 13 | say
# Processing Record 5 of Set 13 | trinidad
# Processing Record 6 of Set 13 | karratha
# Processing Record 7 of Set 13 | shelburne
# Processing Record 8 of Set 13 | dalbandin
# Processing Record 9 of Set 13 | kendari
# Processing Record 10 of Set 13 | kusk
# City not found. Skipping...
# Processing Record 11 of Set 13 | oktyabrskoye
# Processing Record 12 of Set 13 | yakeshi
# Processing Record 13 of Set 13 | bolshiye uki
# City not found. Skipping...
# Processing Record 14 of Set 13 | necochea
# Processing Record 15 of Set 13 | one hundred mile house
# City not found. Skipping...
# Processing Record 16 of Set 13 | rapid valley
# Processing Record 17 of Set 13 | ribas do rio pardo
# Processing Record 18 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 19 of Set 13 | boffa
# Processing Record 20 of Set 13 | acajutla
# Processing Record 21 of Set 13 | andenes
# Processing Record 22 of Set 13 | acarau
# Processing Record 23 of Set 13 | canon city
# Processing Record 24 of Set 13 | rumphi
# Processing Record 25 of Set 13 | marrakesh
# Processing Record 26 of Set 13 | musoma
# Processing Record 27 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 13 | san borja
# Processing Record 29 of Set 13 | karakose
# City not found. Skipping...
# Processing Record 30 of Set 13 | jumla
# Processing Record 31 of Set 13 | dao
# Processing Record 32 of Set 13 | potgietersrus
# City not found. Skipping...
# Processing Record 33 of Set 13 | katherine
# Processing Record 34 of Set 13 | svetlaya
# Processing Record 35 of Set 13 | ugoofaaru
# Processing Record 36 of Set 13 | bestobe
# Processing Record 37 of Set 13 | kyren
# Processing Record 38 of Set 13 | sawakin
# Processing Record 39 of Set 13 | katangli
# Processing Record 40 of Set 13 | digha
# Processing Record 41 of Set 13 | tautira
# Processing Record 42 of Set 13 | honningsvag
# Processing Record 43 of Set 13 | ahipara
# Processing Record 44 of Set 13 | iacu
# Processing Record 45 of Set 13 | rexburg
# Processing Record 46 of Set 13 | haines junction
# Processing Record 47 of Set 13 | takoradi
# Processing Record 48 of Set 13 | krasnoselkup
# Processing Record 49 of Set 13 | lisakovsk
# Processing Record 50 of Set 13 | waddan
# Processing Record 1 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 2 of Set 14 | dombovar
# Processing Record 3 of Set 14 | moissac
# Processing Record 4 of Set 14 | gusau
# Processing Record 5 of Set 14 | bani
# Processing Record 6 of Set 14 | sanchazi
# Processing Record 7 of Set 14 | alvorada
# Processing Record 8 of Set 14 | dongzhen
# Processing Record 9 of Set 14 | port hawkesbury
# Processing Record 10 of Set 14 | casa nova
# Processing Record 11 of Set 14 | richards bay
# Processing Record 12 of Set 14 | lodingen
# Processing Record 13 of Set 14 | amparafaravola
# Processing Record 14 of Set 14 | thoen
# Processing Record 15 of Set 14 | nabire
# Processing Record 16 of Set 14 | olimpia
# Processing Record 17 of Set 14 | palu
# Processing Record 18 of Set 14 | bluefields
# Processing Record 19 of Set 14 | samarai
# Processing Record 20 of Set 14 | kalat
# Processing Record 21 of Set 14 | south venice
# Processing Record 22 of Set 14 | saint pete beach
# Processing Record 23 of Set 14 | denpasar
# Processing Record 24 of Set 14 | folldal
# Processing Record 25 of Set 14 | manhattan
# Processing Record 26 of Set 14 | poum
# Processing Record 27 of Set 14 | mariental
# Processing Record 28 of Set 14 | eureka
# Processing Record 29 of Set 14 | caravelas
# Processing Record 30 of Set 14 | quelimane
# Processing Record 31 of Set 14 | floro
# Processing Record 32 of Set 14 | qom
# Processing Record 33 of Set 14 | neiafu
# Processing Record 34 of Set 14 | eydhafushi
# Processing Record 35 of Set 14 | rio verde de mato grosso
# Processing Record 36 of Set 14 | najran
# Processing Record 37 of Set 14 | hirara
# Processing Record 38 of Set 14 | brodnica
# Processing Record 39 of Set 14 | lodwar
# Processing Record 40 of Set 14 | lieksa
# Processing Record 41 of Set 14 | aporawan
# City not found. Skipping...
# Processing Record 42 of Set 14 | sembakung
# Processing Record 43 of Set 14 | kuusankoski
# Processing Record 44 of Set 14 | irupi
# Processing Record 45 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 14 | ahuimanu
# Processing Record 47 of Set 14 | hofn
# Processing Record 48 of Set 14 | ulladulla
# Processing Record 49 of Set 14 | senador jose porfirio
# Processing Record 50 of Set 14 | agua dulce
# Processing Record 1 of Set 15 | torit
# Processing Record 2 of Set 15 | anadyr
# Processing Record 3 of Set 15 | rio negrinho
# Processing Record 4 of Set 15 | elko
# Processing Record 5 of Set 15 | simao
# Processing Record 6 of Set 15 | pangody
# Processing Record 7 of Set 15 | cheremukhovo
# Processing Record 8 of Set 15 | palasa
# Processing Record 9 of Set 15 | saint-joseph
# Processing Record 10 of Set 15 | nyurba
# Processing Record 11 of Set 15 | pangai
# Processing Record 12 of Set 15 | sola
# Processing Record 13 of Set 15 | delijan
# Processing Record 14 of Set 15 | coroico
# Processing Record 15 of Set 15 | aswan
# Processing Record 16 of Set 15 | isiro
# Processing Record 17 of Set 15 | charters towers
# Processing Record 18 of Set 15 | mezen
# Processing Record 19 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 15 | kokopo
# Processing Record 21 of Set 15 | jijiang
# Processing Record 22 of Set 15 | high level
# Processing Record 23 of Set 15 | tete
# Processing Record 24 of Set 15 | tiarei
# Processing Record 25 of Set 15 | praxedis guerrero
# Processing Record 26 of Set 15 | chara
# Processing Record 27 of Set 15 | kargopol
# Processing Record 28 of Set 15 | vanimo
# Processing Record 29 of Set 15 | coronado
# Processing Record 30 of Set 15 | severodvinsk
# Processing Record 31 of Set 15 | scottsbluff
# Processing Record 32 of Set 15 | jacobina
# Processing Record 33 of Set 15 | menongue
# Processing Record 34 of Set 15 | tarauaca
# Processing Record 35 of Set 15 | eldorado
# Processing Record 36 of Set 15 | beaverlodge
# Processing Record 37 of Set 15 | vallenar
# Processing Record 38 of Set 15 | general roca
# Processing Record 39 of Set 15 | araceli
# Processing Record 40 of Set 15 | aipe
# Processing Record 41 of Set 15 | pavilosta
# Processing Record 42 of Set 15 | santarem
# Processing Record 43 of Set 15 | gazanjyk
# Processing Record 44 of Set 15 | dunedin
# Processing Record 45 of Set 15 | pathein
# Processing Record 46 of Set 15 | wampusirpi
# City not found. Skipping...
# Processing Record 47 of Set 15 | lubbock
# Processing Record 48 of Set 15 | eyl
# Processing Record 49 of Set 15 | terny
# Processing Record 50 of Set 15 | mitu
# Processing Record 1 of Set 16 | kuytun
# Processing Record 2 of Set 16 | puerto del rosario
# Processing Record 3 of Set 16 | villacarrillo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe      re -21.3585   55.7679     78.80        78          20
# 1         Algiers      dz  36.7525    3.0420     55.40        82          20
# 2           Batie      bf   9.8833   -2.9167     81.41        19          14
# 3  Port Macquarie      au -31.4333  152.9167     70.00        94          75
# 4    Puerto Ayora      ec  -0.7393  -90.3518     77.00        95          10
# 5          Narsaq      gl  60.9167  -46.0500     30.20        86          75
# 6      Sao Filipe      cv  14.8961  -24.4956     70.05        76          37
# 7         Mataura      pf -46.1927  168.8643     62.01        67         100
# 8       Hithadhoo      mv  -0.6000   73.0833     83.91        76          88
# 9     Tuktoyaktuk      ca  69.4541 -133.0374    -11.20        70          40
#
#    Wind Speed Weather description
# 0       13.80          light rain
# 1        3.44          few clouds
# 2        3.56          few clouds
# 3        4.61       broken clouds
# 4        4.00           clear sky
# 5        1.14          light snow
# 6        7.61    scattered clouds
# 7        4.00     overcast clouds
# 8       20.24     overcast clouds
# 9       21.85                snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
